# %%
from core.main import main

out1, out2 = main()

out1
out1.show()
out2.show()
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Test Case: logical
# ...
#
# Testing saliency on: If we know that all A are B, and all B are C, then what can we conclude about A and C?
#
# Testing integrated_gradients on: If we know that all A are B, and all B are C, then what can we conclude about A and C?
#
# Testing input_x_gradient on: If we know that all A are B, and all B are C, then what can we conclude about A and C?
#
# Testing attention on: If we know that all A are B, and all B are C, then what can we conclude about A and C?
#
# Testing occlusion on: If we know that all A are B, and all B are C, then what can we conclude about A and C?
#
# ...
# Test Case: world_knowledge
# ...
#
# Testing saliency on: The Great Wall of China was built over many centuries. The main dynasty responsible for its current form was
#
# Testing integrated_gradients on: The Great Wall of China was built over many centuries. The main dynasty responsible for its current form was
#
# ...
